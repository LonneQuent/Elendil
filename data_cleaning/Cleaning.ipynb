# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_customers = pd.read_csv("olist_customers_dataset.csv")
df_sellers = pd.read_csv("olist_sellers_dataset.csv")
df_order_reviews = pd.read_csv("olist_order_reviews_dataset.csv")
df_order_items = pd.read_csv("olist_order_items_dataset.csv")
df_products = pd.read_csv("olist_products_dataset.csv")
df_category_name_translation = pd.read_csv("product_category_name_translation.csv")
df_orders = pd.read_csv("olist_orders_dataset.csv")
df_order_payments = pd.read_csv("olist_order_payments_dataset.csv")

# %%
df_order_payments = df_order_payments.drop(['payment_sequential','payment_installments','payment_value'], axis=1)

# %%
list_df = [df_customers, df_sellers, df_order_reviews, df_order_items, df_products, df_category_name_translation ,df_orders, df_order_payments]

# %%
merged_df = pd.merge(df_order_items, df_orders, on='order_id', how='left')
print(merged_df.shape)

merged_df2 = pd.merge(merged_df, df_customers, on='customer_id', how='left')
print(merged_df2.shape)

merged_df3 = pd.merge(merged_df2, df_products, on='product_id', how='left')
print(merged_df3.shape)

merged_df5 = pd.merge(merged_df3, df_category_name_translation, on='product_category_name', how='left')
print(merged_df5.shape)

merged_df4 = pd.merge(merged_df5, df_order_payments, on='order_id', how='left')
print(merged_df4.shape)

df_final = pd.merge(merged_df4, df_order_reviews, on='order_id', how='left')
print(df_final.shape)
# Out:
# (112650, 14)
# (112650, 18)
# (112650, 26)
# (112650, 27)
# (117604, 28)
# (118310, 34)

# %% [markdown]
# # Netoyage + analyse des données

# %%
df_final = df_final.drop(['product_category_name', 'order_approved_at', 'seller_id','shipping_limit_date', 'customer_unique_id', 'customer_zip_code_prefix', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm', 'review_id', 'review_comment_title', 'review_creation_date', 'review_answer_timestamp'], axis=1)

# %%
df_final = df_final.rename(columns = {'product_category_name_english': 'product_category_name'})

# %%
df_final =df_final.drop_duplicates()

# %%
df_final.shape
# Out:
# (115543, 17)

# %%
df_final['payment_type'] = df_final['payment_type'].replace({'boleto':'cash', 'voucher': "gift_card"})
# Out:
# <ipython-input-17-c546f7a88969>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['payment_type'] = df_final['payment_type'].replace({'boleto':'cash', 'voucher': "gift_card"})

# %%
state_name = {
"AC" : "Acre",
"AL" : "Alagoas",
"AM" : "Amazonas",
"AP" : "Amapa",
"BA" : "Bahia",
"CE" : "Ceara",
"DF" : "Distrito Federal",
"ES" : "Espirito Santo",
"GO" : "Goias",
"MA" : "Maranhao",
"MG" : "Minas Gerais",
"MS" : "Mato Grosso do Sul",
"MT" : "Mato Grosso",
"PA" : "Para",
"PB" : "Paraiba",
"PE" : "Pernambuco",
"PI" : "Piaui",
"PR" : "Parana",
"RJ" : "Rio de Janeiro",
"RN" : "Rio Grande do Norte",
"RO" : "Rondonia",
"RR" : "Roraima",
"RS" : "Rio Grande do Sul",
"SC" : "Santa Catarina",
"SE" : "Sergipe",
"SP" : "Sao Paulo",
"TO" : "Tocantins"
}

# %%
df_final['customer_state'] = df_final['customer_state'].map(state_name)

# %%
df_final['date_only'] = pd.to_datetime(df_final['order_date']).dt.date

# %%
df_final.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id   price  freight_value  \
# 0  4244733e06e7ecb4970a6e2683c13e61   58.90          13.29
# 1  e5f2d52b802189ee658865ca93d83a8f  239.90          19.93
# 2  c777355d18b72b67abbeef9df44fd0fd  199.00          17.87
# 3  7634da152a4610f1595efa32f14722fc   12.99          12.79
# 4  ac6c3623068f30de03045865e4e10089  199.90          18.14
#
#                         customer_id order_status          order_date  \
# 0  3ce436f183e68e07877b285a838db11a    delivered 2017-09-13 08:59:02
# 1  f6dd3ec061db4e3987629fe6b26e5cce    delivered 2017-04-26 10:53:06
# 2  6489ae5e4333f3693df5ad4372dab6d3    delivered 2018-01-14 14:33:31
# ...

# %%
df_final = df_final.rename(columns={"order_purchase_timestamp": "order_date",
                                        "order_delivered_carrier_date": "shipped_date",
                                        "order_delivered_customer_date": "delivery_date"})

# %%
dt_columns = ['order_date', 'shipped_date', 'delivery_date']

for column in dt_columns:
  df_final[column] = pd.to_datetime(df_final[column])

# %%
df_panier_group = df_final.groupby('order_id').agg({
    'order_item_id': 'max',  # Garde le order_item_id max
    'product_id': lambda x: list(x),  # Crée une liste de tous les produits
    'price': 'sum',  # Somme de price
    'freight_value': 'first',  # Garde la première valeur de freight_value
    'product_category_name': lambda x: list(x)
}).reset_index()

df_panier_group['total_price'] = df_panier_group['price'] + df_panier_group['freight_value']
df_panier_group['date'] = df_final['date_only']
df_panier_group['customer_id'] = df_final['customer_id']
df_panier_group = df_panier_group.rename(columns={"order_item_id":"nb_article_panier"})

# %%
nb_moyen_article_par_panier = df_panier_group['nb_article_panier'].sum()/len(df_panier_group['order_id'])
nb_moyen_article_par_panier
# Out:
# 1.1417306873695092

# %%
df_panier_group.head()
# Out:
#                            order_id  nb_article_panier  \
# 0  00010242fe8c5a6d1ba2dd792cb16214                  1
# 1  00018f77f2f0320c557190d7a144bdd3                  1
# 2  000229ec398224ef6ca0657da4fc703e                  1
# 3  00024acbcdf0a6daa1e931b038114c75                  1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9                  1
#
#                            product_id   price  freight_value  \
# 0  [4244733e06e7ecb4970a6e2683c13e61]   58.90          13.29
# 1  [e5f2d52b802189ee658865ca93d83a8f]  239.90          19.93
# 2  [c777355d18b72b67abbeef9df44fd0fd]  199.00          17.87
# 3  [7634da152a4610f1595efa32f14722fc]   12.99          12.79
# 4  [ac6c3623068f30de03045865e4e10089]  199.90          18.14
#
#   product_category_name  total_price        date  \
# 0          [cool_stuff]        72.19  2017-09-13
# 1            [pet_shop]       259.83  2017-04-26
# 2     [furniture_decor]       216.87  2018-01-14
# 3           [perfumery]        25.78  2018-08-08
# ...

# %%
df_final.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id   price  freight_value  \
# 0  4244733e06e7ecb4970a6e2683c13e61   58.90          13.29
# 1  e5f2d52b802189ee658865ca93d83a8f  239.90          19.93
# 2  c777355d18b72b67abbeef9df44fd0fd  199.00          17.87
# 3  7634da152a4610f1595efa32f14722fc   12.99          12.79
# 4  ac6c3623068f30de03045865e4e10089  199.90          18.14
#
#                         customer_id order_status          order_date  \
# 0  3ce436f183e68e07877b285a838db11a    delivered 2017-09-13 08:59:02
# 1  f6dd3ec061db4e3987629fe6b26e5cce    delivered 2017-04-26 10:53:06
# 2  6489ae5e4333f3693df5ad4372dab6d3    delivered 2018-01-14 14:33:31
# ...

# %%
customers_in_cities = df_final.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False).reset_index()
customers_in_cities.head(10)
# Out:
#            customer_city  customer_id
# 0              sao paulo        15402
# 1         rio de janeiro         6834
# 2         belo horizonte         2750
# 3               brasilia         2116
# 4               curitiba         1510
# 5               campinas         1429
# 6           porto alegre         1372
# 7               salvador         1238
# 8              guarulhos         1178
# 9  sao bernardo do campo          928

# %%
customers_in_states = df_final.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False).reset_index()
customers_in_states.head(10)
# Out:
#       customer_state  customer_id
# 0          Sao Paulo        41375
# 1     Rio de Janeiro        12762
# 2       Minas Gerais        11544
# 3  Rio Grande do Sul         5432
# 4             Parana         4998
# 5     Santa Catarina         3612
# 6              Bahia         3358
# 7   Distrito Federal         2125
# 8     Espirito Santo         2025
# 9              Goias         2007

# %%
order_by_product_category = df_final.groupby(by="product_category_name").agg(num_of_order = ('order_id','count'), sum_order_value = ('price', 'sum')).reset_index()
order_by_product_category.sort_values(by=['num_of_order','sum_order_value'], ascending=False).head(10)
# Out:
#     product_category_name  num_of_order  sum_order_value
# 7          bed_bath_table         11511       1070293.31
# 43          health_beauty          9851       1280478.87
# 65         sports_leisure          8842       1007371.03
# 39        furniture_decor          8605        752016.60
# 15  computers_accessories          8019        932811.33
# 49             housewares          7154        648166.64
# 70          watches_gifts          6117       1233752.10
# 68              telephony          4641        330989.55
# 42           garden_tools          4451        493777.39
# 5                    auto          4333        608036.37

# %%
order_by_product_category.sort_values('num_of_order', ascending=True).head(10)
# Out:
#                 product_category_name  num_of_order  sum_order_value
# 61              security_and_services             2           283.29
# 29          fashion_childrens_clothes             8           569.85
# 11                  cds_dvds_musicals            14           730.00
# 52                         la_cuisine            16          2303.98
# 3               arts_and_craftmanship            24          1814.01
# 32                      fashion_sport            30          2119.51
# 46                     home_comfort_2            31           773.17
# 35                            flowers            33          1110.04
# 23                diapers_and_hygiene            39          1567.59
# 41  furniture_mattress_and_upholstery            39          4477.48

# %%
oldest_order = df_orders['order_purchase_timestamp'].min()
newest_order = df_orders['order_purchase_timestamp'].max()

print ("The oldest order was: ", oldest_order)
print ("The newest order was: ", newest_order)
# Out:
# The oldest order was:  2016-09-04 21:15:19
# The newest order was:  2018-10-17 17:30:18

# %%
category_scores = df_final.groupby('product_category_name')['review_score'].mean().sort_values(ascending=False)

top_score = pd.DataFrame(category_scores.head(5))
lowest_score = pd.DataFrame(category_scores.tail(5))
print (top_score)
print (lowest_score)
# Out:
#                            review_score
# product_category_name
# cds_dvds_musicals              4.642857
# fashion_childrens_clothes      4.500000
# books_general_interest         4.442652
# flowers                        4.419355
# books_imported                 4.419355
#                        review_score
# product_category_name
# home_comfort_2             3.642857
# fashion_male_clothing      3.535714
# office_furniture           3.495627
# diapers_and_hygiene        3.256410
# security_and_services      2.500000
